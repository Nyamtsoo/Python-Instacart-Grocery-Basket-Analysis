# %%
# Importing libraries
import pandas as pd
import numpy as np
import os

# %%
path = r'C:\Users\jnyam\Documents\Instacart Basket Analysis'

# %%
ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data','Prepared Data', 'ords_prods_merged_7.pkl'))

# %%
df = ords_prods_merge[:1000000]

# %%
df.shape
# Out:
# (1000000, 19)

# %%
df.head(10)
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
# 5   3367565        1             6                   2                  7
# 6    550135        1             7                   1                  9
# 7   3108588        1             8                   1                 14
# 8   2295261        1             9                   1                 16
# 9   2550362        1            10                   4                  8
#
#    days_since_prior_order  new_customer  product_id  add_to_cart_order  \
# 0                     NaN          True       196.0                1.0
# 1                    15.0         False       196.0                1.0
# 2                    21.0         False       196.0                1.0
# 3                    29.0         False       196.0                1.0
# 4                    28.0         False       196.0                1.0
# 5                    19.0         False       196.0                1.0
# 6                    20.0         False       196.0                1.0
# 7                    14.0         False       196.0                2.0
# 8                     0.0         False       196.0                4.0
# 9                    30.0         False       196.0                1.0
#
#    reordered _merge product_name  aisle_id  department_id  prices  \
# 0        0.0   both         Soda        77              7     9.0
# 1        1.0   both         Soda        77              7     9.0
# 2        1.0   both         Soda        77              7     9.0
# 3        1.0   both         Soda        77              7     9.0
# 4        1.0   both         Soda        77              7     9.0
# 5        1.0   both         Soda        77              7     9.0
# 6        1.0   both         Soda        77              7     9.0
# 7        1.0   both         Soda        77              7     9.0
# 8        1.0   both         Soda        77              7     9.0
# 9        1.0   both         Soda        77              7     9.0
#
#      price_range_loc     busiest_day Busiest_day_two busiest_period_of_day
# 0  Mid-range product  Regularly busy  Regularly busy        Average orders
# 1  Mid-range product  Regularly busy      Least busy        Average orders
# 2  Mid-range product  Regularly busy      Least busy           Most orders
# 3  Mid-range product      Least busy      Least busy        Average orders
# 4  Mid-range product      Least busy      Least busy           Most orders
# 5  Mid-range product  Regularly busy  Regularly busy        Average orders
# 6  Mid-range product  Regularly busy     Busiest day        Average orders
# 7  Mid-range product  Regularly busy     Busiest day           Most orders
# 8  Mid-range product  Regularly busy     Busiest day           Most orders
# 9  Mid-range product      Least busy      Least busy        Average orders

# %%
df.groupby('product_name')

# %%
# Performing a Single Aggregation
df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 4                18.825780
# 7                17.472355
# 13               17.993423
# 14               19.246334
# 16               19.463012
# 17               11.294069
# 19               19.305237
# 20               17.599636

# %%
df.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 4     18.825780
# 7     17.472355
# 13    17.993423
# 14    19.246334
# 16    19.463012
# 17    11.294069
# 19    19.305237
# 20    17.599636
# Name: order_number, dtype: float64

# %%
df.groupby('department_id').order_number.mean()
# Out:
# department_id
# 4     18.825780
# 7     17.472355
# 13    17.993423
# 14    19.246334
# 16    19.463012
# 17    11.294069
# 19    19.305237
# 20    17.599636
# Name: order_number, dtype: float64

# %%
# Performing Multiple Aggregations
df.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 4                18.825780   1  99
# 7                17.472355   1  99
# 13               17.993423   1  99
# 14               19.246334   1  99
# 16               19.463012   1  99
# 17               11.294069   1  98
# 19               19.305237   1  99
# 20               17.599636   1  99

# %% [markdown]
# ### Aggregating Data with transform()

# %% [markdown]
# ##### Create a loyalty flag using loc

# %%
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
ords_prods_merge.head(15)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                   2                  8
# 1    2398795        1             2                   3                  7
# 2     473747        1             3                   3                 12
# 3    2254736        1             4                   4                  7
# 4     431534        1             5                   4                 15
# 5    3367565        1             6                   2                  7
# 6     550135        1             7                   1                  9
# 7    3108588        1             8                   1                 14
# 8    2295261        1             9                   1                 16
# 9    2550362        1            10                   4                  8
# 10   2968173       15            15                   1                  9
# 11   1870022       15            17                   2                 16
# 12   1911383       15            18                   2                 11
# 13   2715276       15            21                   1                  9
# 14    487368       15            22                   1                 10
#
#     days_since_prior_order  new_customer  product_id  add_to_cart_order  \
# 0                      NaN          True       196.0                1.0
# 1                     15.0         False       196.0                1.0
# 2                     21.0         False       196.0                1.0
# 3                     29.0         False       196.0                1.0
# 4                     28.0         False       196.0                1.0
# 5                     19.0         False       196.0                1.0
# 6                     20.0         False       196.0                1.0
# 7                     14.0         False       196.0                2.0
# 8                      0.0         False       196.0                4.0
# 9                     30.0         False       196.0                1.0
# 10                     7.0         False       196.0                2.0
# 11                     8.0         False       196.0                6.0
# 12                     7.0         False       196.0                1.0
# 13                     7.0         False       196.0                1.0
# 14                    14.0         False       196.0                1.0
#
#     reordered _merge product_name  aisle_id  department_id  prices  \
# 0         0.0   both         Soda        77              7     9.0
# 1         1.0   both         Soda        77              7     9.0
# 2         1.0   both         Soda        77              7     9.0
# 3         1.0   both         Soda        77              7     9.0
# 4         1.0   both         Soda        77              7     9.0
# 5         1.0   both         Soda        77              7     9.0
# 6         1.0   both         Soda        77              7     9.0
# 7         1.0   both         Soda        77              7     9.0
# 8         1.0   both         Soda        77              7     9.0
# 9         1.0   both         Soda        77              7     9.0
# 10        0.0   both         Soda        77              7     9.0
# 11        1.0   both         Soda        77              7     9.0
# 12        1.0   both         Soda        77              7     9.0
# 13        1.0   both         Soda        77              7     9.0
# 14        1.0   both         Soda        77              7     9.0
#
#       price_range_loc     busiest_day Busiest_day_two busiest_period_of_day  \
# 0   Mid-range product  Regularly busy  Regularly busy        Average orders
# 1   Mid-range product  Regularly busy      Least busy        Average orders
# 2   Mid-range product  Regularly busy      Least busy           Most orders
# 3   Mid-range product      Least busy      Least busy        Average orders
# 4   Mid-range product      Least busy      Least busy           Most orders
# 5   Mid-range product  Regularly busy  Regularly busy        Average orders
# 6   Mid-range product  Regularly busy     Busiest day        Average orders
# 7   Mid-range product  Regularly busy     Busiest day           Most orders
# 8   Mid-range product  Regularly busy     Busiest day           Most orders
# 9   Mid-range product      Least busy      Least busy        Average orders
# 10  Mid-range product  Regularly busy     Busiest day        Average orders
# 11  Mid-range product  Regularly busy  Regularly busy           Most orders
# 12  Mid-range product  Regularly busy  Regularly busy           Most orders
# 13  Mid-range product  Regularly busy     Busiest day        Average orders
# 14  Mid-range product  Regularly busy     Busiest day           Most orders
#
#     max_order
# 0          10
# 1          10
# 2          10
# 3          10
# 4          10
# 5          10
# 6          10
# 7          10
# 8          10
# 9          10
# 10         22
# 11         22
# 12         22
# 13         22
# 14         22

# %%
# This command tells pandas not to assign any options regarding the maximum number of rows to display.
pd.options.display.max_rows = None

# %%
ords_prods_merge.head(100)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                   2                  8
# 1    2398795        1             2                   3                  7
# 2     473747        1             3                   3                 12
# 3    2254736        1             4                   4                  7
# 4     431534        1             5                   4                 15
# 5    3367565        1             6                   2                  7
# 6     550135        1             7                   1                  9
# 7    3108588        1             8                   1                 14
# 8    2295261        1             9                   1                 16
# 9    2550362        1            10                   4                  8
# 10   2968173       15            15                   1                  9
# 11   1870022       15            17                   2                 16
# 12   1911383       15            18                   2                 11
# 13   2715276       15            21                   1                  9
# 14    487368       15            22                   1                 10
# 15   2293453       19             2                   5                 14
# 16   1973799       19             5                   6                 12
# 17    532817       19             7                   4                 17
# 18   1573906       21            10                   3                 10
# 19   1593000       31            10                   3                  8
# 20   2231262       31            17                   3                 11
# 21   2580647       43             6                   4                 16
# 22   2187180       43             9                   4                 12
# 23   2497897       52             1                   1                  9
# 24   1318871       52             2                   1                 10
# 25   1261384       52             3                   1                 10
# 26    580568       52             5                   2                 10
# 27   2428073       52             7                   2                  7
# 28    342306       52             9                   1                 11
# 29   1520353       52            10                   2                 10
# 30   2542086       52            11                   2                  9
# 31    944694       52            12                   1                 16
# 32   1268191       52            15                   2                 11
# 33   1122089       52            17                   2                 10
# 34   1498922       52            18                   2                 10
# 35    180919       52            19                   3                  8
# 36   2695875       52            21                   5                 10
# 37   3205960       67             1                   3                 11
# 38    970922       67             2                   1                 15
# 39    596585       67             3                   1                 13
# 40   2037087       67             4                   2                  9
# 41   2474111       67             5                   3                 14
# 42   1568481       67             6                   3                 12
# 43   2048527       67             8                   2                 11
# 44   2389031       67             9                   2                 14
# 45   2378562       67            10                   1                 10
# 46   1515698       67            11                   1                 11
# 47   1928050       67            12                   2                 12
# 48   1949274       67            13                   1                 10
# 49    551869       67            14                   1                  9
# 50    768572       67            16                   4                 10
# 51    150528       67            18                   5                 16
# 52     29758       67            19                   0                 14
# 53   1558976       67            21                   1                  9
# 54    863974       67            22                   1                 11
# 55   2308399       67            23                   1                 14
# 56   2759128       81             3                   1                  9
# 57   1812985       81             5                   2                 20
# 58   1889835       82             1                   3                 15
# 59    499460       82             3                   5                 10
# 60   2728456       82             4                   0                 11
# 61   2653743       82             6                   4                  9
# 62   1358880       82             9                   1                 10
# 63    343588       82            10                   2                 11
# 64   3034663       82            15                   2                 11
# 65    147262       82            18                   1                 13
# 66   3144004       82            19                   2                 15
# 67   2126069       98             3                   0                  9
# 68   2210120       98             7                   5                 14
# 69    681011       98             9                   3                  9
# 70   2846344       98            11                   4                 13
# 71    747431       98            12                   6                 13
# 72   2383054       98            13                   4                 11
# 73   1993729       98            14                   5                  8
# 74   1403849      109             3                   3                 17
# 75    520620      120             1                   3                 11
# 76   3273029      120             3                   2                  8
# 77   1861943      185             2                   1                 12
# 78   2040988      195             1                   1                 14
# 79   1680569      195             8                   1                  9
# 80    276171      195            19                   5                 11
# 81   2744976      195            22                   5                 10
# 82   2781919      195            25                   1                 14
# 83   1738718      195            31                   2                  8
# 84   3058369      195            34                   3                 10
# 85   1485596      195            37                   2                 15
# 86    417035      195            40                   3                 16
# 87   1615297      195            47                   5                 10
# 88   1765587      195            52                   3                 12
# 89    745908      195            57                   4                 11
# 90   2505656      222            17                   2                 12
# 91   3268370      222            38                   5                 15
# 92   2016711      290             9                   5                 19
# 93   2706088      290            28                   6                 10
# 94   1952286      331             6                   5                 16
# 95   3226575      360             1                   5                 12
# 96   1469869      377             3                   5                 17
# 97   1927023      387             2                   4                 10
# 98    858092      420             4                   1                 19
# 99    119314      420             5                   3                 19
#
#     days_since_prior_order  new_customer  product_id  add_to_cart_order  \
# 0                      NaN          True       196.0                1.0
# 1                     15.0         False       196.0                1.0
# 2                     21.0         False       196.0                1.0
# 3                     29.0         False       196.0                1.0
# 4                     28.0         False       196.0                1.0
# 5                     19.0         False       196.0                1.0
# 6                     20.0         False       196.0                1.0
# 7                     14.0         False       196.0                2.0
# 8                      0.0         False       196.0                4.0
# 9                     30.0         False       196.0                1.0
# 10                     7.0         False       196.0                2.0
# 11                     8.0         False       196.0                6.0
# 12                     7.0         False       196.0                1.0
# 13                     7.0         False       196.0                1.0
# 14                    14.0         False       196.0                1.0
# 15                     6.0         False       196.0                3.0
# 16                     8.0         False       196.0               15.0
# 17                     6.0         False       196.0                1.0
# 18                     6.0         False       196.0                2.0
# 19                     7.0         False       196.0               17.0
# 20                     8.0         False       196.0               14.0
# 21                     4.0         False       196.0                9.0
# 22                     3.0         False       196.0                1.0
# 23                     NaN          True       196.0                4.0
# 24                     7.0         False       196.0                5.0
# 25                     7.0         False       196.0                3.0
# 26                     8.0         False       196.0                6.0
# 27                     8.0         False       196.0                5.0
# 28                     7.0         False       196.0                5.0
# 29                     8.0         False       196.0                4.0
# 30                     7.0         False       196.0                3.0
# 31                     6.0         False       196.0                7.0
# 32                     8.0         False       196.0                3.0
# 33                     6.0         False       196.0                4.0
# 34                    14.0         False       196.0                6.0
# 35                     8.0         False       196.0                4.0
# 36                    30.0         False       196.0                1.0
# 37                     NaN          True       196.0                1.0
# 38                     5.0         False       196.0                2.0
# 39                     7.0         False       196.0                2.0
# 40                     8.0         False       196.0                1.0
# 41                     8.0         False       196.0                2.0
# 42                     7.0         False       196.0                2.0
# 43                     7.0         False       196.0                1.0
# 44                     7.0         False       196.0                1.0
# 45                     6.0         False       196.0                1.0
# 46                     7.0         False       196.0                1.0
# 47                     8.0         False       196.0                1.0
# 48                     6.0         False       196.0                1.0
# 49                     7.0         False       196.0                1.0
# 50                     9.0         False       196.0                1.0
# 51                     4.0         False       196.0                1.0
# 52                     9.0         False       196.0                2.0
# 53                     5.0         False       196.0                2.0
# 54                    14.0         False       196.0                3.0
# 55                    14.0         False       196.0                1.0
# 56                    14.0         False       196.0                2.0
# 57                    30.0         False       196.0                1.0
# 58                     NaN          True       196.0                6.0
# 59                     5.0         False       196.0                2.0
# 60                    16.0         False       196.0                1.0
# 61                    13.0         False       196.0                5.0
# 62                    30.0         False       196.0                1.0
# 63                     1.0         False       196.0                1.0
# 64                    12.0         False       196.0                1.0
# 65                     7.0         False       196.0                1.0
# 66                     8.0         False       196.0                1.0
# 67                    25.0         False       196.0                7.0
# 68                     5.0         False       196.0                1.0
# 69                    30.0         False       196.0                1.0
# 70                    15.0         False       196.0                2.0
# 71                    30.0         False       196.0                4.0
# 72                    30.0         False       196.0                1.0
# 73                     8.0         False       196.0                2.0
# 74                     9.0         False       196.0                5.0
# 75                     NaN          True       196.0                2.0
# 76                    19.0         False       196.0                2.0
# 77                    25.0         False       196.0               10.0
# 78                     NaN          True       196.0                2.0
# 79                     4.0         False       196.0                2.0
# 80                     3.0         False       196.0                2.0
# 81                     7.0         False       196.0                2.0
# 82                     4.0         False       196.0                1.0
# 83                     4.0         False       196.0                2.0
# 84                     6.0         False       196.0                2.0
# 85                     0.0         False       196.0                2.0
# 86                     2.0         False       196.0                2.0
# 87                     2.0         False       196.0                2.0
# 88                     2.0         False       196.0                3.0
# 89                     3.0         False       196.0                3.0
# 90                     1.0         False       196.0                2.0
# 91                     1.0         False       196.0                6.0
# 92                     6.0         False       196.0                8.0
# 93                     7.0         False       196.0               16.0
# 94                    30.0         False       196.0                8.0
# 95                     NaN          True       196.0                1.0
# 96                     3.0         False       196.0                9.0
# 97                    22.0         False       196.0                3.0
# 98                    30.0         False       196.0                2.0
# 99                    16.0         False       196.0                2.0
#
#     reordered _merge product_name  aisle_id  department_id  prices  \
# 0         0.0   both         Soda        77              7     9.0
# 1         1.0   both         Soda        77              7     9.0
# 2         1.0   both         Soda        77              7     9.0
# 3         1.0   both         Soda        77              7     9.0
# 4         1.0   both         Soda        77              7     9.0
# 5         1.0   both         Soda        77              7     9.0
# 6         1.0   both         Soda        77              7     9.0
# 7         1.0   both         Soda        77              7     9.0
# 8         1.0   both         Soda        77              7     9.0
# 9         1.0   both         Soda        77              7     9.0
# 10        0.0   both         Soda        77              7     9.0
# 11        1.0   both         Soda        77              7     9.0
# 12        1.0   both         Soda        77              7     9.0
# 13        1.0   both         Soda        77              7     9.0
# 14        1.0   both         Soda        77              7     9.0
# 15        0.0   both         Soda        77              7     9.0
# 16        1.0   both         Soda        77              7     9.0
# 17        1.0   both         Soda        77              7     9.0
# 18        0.0   both         Soda        77              7     9.0
# 19        0.0   both         Soda        77              7     9.0
# 20        1.0   both         Soda        77              7     9.0
# 21        0.0   both         Soda        77              7     9.0
# 22        1.0   both         Soda        77              7     9.0
# 23        0.0   both         Soda        77              7     9.0
# 24        1.0   both         Soda        77              7     9.0
# 25        1.0   both         Soda        77              7     9.0
# 26        1.0   both         Soda        77              7     9.0
# 27        1.0   both         Soda        77              7     9.0
# 28        1.0   both         Soda        77              7     9.0
# 29        1.0   both         Soda        77              7     9.0
# 30        1.0   both         Soda        77              7     9.0
# 31        1.0   both         Soda        77              7     9.0
# 32        1.0   both         Soda        77              7     9.0
# 33        1.0   both         Soda        77              7     9.0
# 34        1.0   both         Soda        77              7     9.0
# 35        1.0   both         Soda        77              7     9.0
# 36        1.0   both         Soda        77              7     9.0
# 37        0.0   both         Soda        77              7     9.0
# 38        1.0   both         Soda        77              7     9.0
# 39        1.0   both         Soda        77              7     9.0
# 40        1.0   both         Soda        77              7     9.0
# 41        1.0   both         Soda        77              7     9.0
# 42        1.0   both         Soda        77              7     9.0
# 43        1.0   both         Soda        77              7     9.0
# 44        1.0   both         Soda        77              7     9.0
# 45        1.0   both         Soda        77              7     9.0
# 46        1.0   both         Soda        77              7     9.0
# 47        1.0   both         Soda        77              7     9.0
# 48        1.0   both         Soda        77              7     9.0
# 49        1.0   both         Soda        77              7     9.0
# 50        1.0   both         Soda        77              7     9.0
# 51        1.0   both         Soda        77              7     9.0
# 52        1.0   both         Soda        77              7     9.0
# 53        1.0   both         Soda        77              7     9.0
# 54        1.0   both         Soda        77              7     9.0
# 55        1.0   both         Soda        77              7     9.0
# 56        0.0   both         Soda        77              7     9.0
# 57        1.0   both         Soda        77              7     9.0
# 58        0.0   both         Soda        77              7     9.0
# 59        1.0   both         Soda        77              7     9.0
# 60        1.0   both         Soda        77              7     9.0
# 61        1.0   both         Soda        77              7     9.0
# 62        1.0   both         Soda        77              7     9.0
# 63        1.0   both         Soda        77              7     9.0
# 64        1.0   both         Soda        77              7     9.0
# 65        1.0   both         Soda        77              7     9.0
# 66        1.0   both         Soda        77              7     9.0
# 67        0.0   both         Soda        77              7     9.0
# 68        1.0   both         Soda        77              7     9.0
# 69        1.0   both         Soda        77              7     9.0
# 70        1.0   both         Soda        77              7     9.0
# 71        1.0   both         Soda        77              7     9.0
# 72        1.0   both         Soda        77              7     9.0
# 73        1.0   both         Soda        77              7     9.0
# 74        0.0   both         Soda        77              7     9.0
# 75        0.0   both         Soda        77              7     9.0
# 76        1.0   both         Soda        77              7     9.0
# 77        0.0   both         Soda        77              7     9.0
# 78        0.0   both         Soda        77              7     9.0
# 79        1.0   both         Soda        77              7     9.0
# 80        1.0   both         Soda        77              7     9.0
# 81        1.0   both         Soda        77              7     9.0
# 82        1.0   both         Soda        77              7     9.0
# 83        1.0   both         Soda        77              7     9.0
# 84        1.0   both         Soda        77              7     9.0
# 85        1.0   both         Soda        77              7     9.0
# 86        1.0   both         Soda        77              7     9.0
# 87        1.0   both         Soda        77              7     9.0
# 88        1.0   both         Soda        77              7     9.0
# 89        1.0   both         Soda        77              7     9.0
# 90        0.0   both         Soda        77              7     9.0
# 91        1.0   both         Soda        77              7     9.0
# 92        0.0   both         Soda        77              7     9.0
# 93        1.0   both         Soda        77              7     9.0
# 94        0.0   both         Soda        77              7     9.0
# 95        0.0   both         Soda        77              7     9.0
# 96        0.0   both         Soda        77              7     9.0
# 97        0.0   both         Soda        77              7     9.0
# 98        0.0   both         Soda        77              7     9.0
# 99        1.0   both         Soda        77              7     9.0
#
#       price_range_loc     busiest_day Busiest_day_two busiest_period_of_day  \
# 0   Mid-range product  Regularly busy  Regularly busy        Average orders
# 1   Mid-range product  Regularly busy      Least busy        Average orders
# 2   Mid-range product  Regularly busy      Least busy           Most orders
# 3   Mid-range product      Least busy      Least busy        Average orders
# 4   Mid-range product      Least busy      Least busy           Most orders
# 5   Mid-range product  Regularly busy  Regularly busy        Average orders
# 6   Mid-range product  Regularly busy     Busiest day        Average orders
# 7   Mid-range product  Regularly busy     Busiest day           Most orders
# 8   Mid-range product  Regularly busy     Busiest day           Most orders
# 9   Mid-range product      Least busy      Least busy        Average orders
# 10  Mid-range product  Regularly busy     Busiest day        Average orders
# 11  Mid-range product  Regularly busy  Regularly busy           Most orders
# 12  Mid-range product  Regularly busy  Regularly busy           Most orders
# 13  Mid-range product  Regularly busy     Busiest day        Average orders
# 14  Mid-range product  Regularly busy     Busiest day           Most orders
# 15  Mid-range product  Regularly busy  Regularly busy           Most orders
# 16  Mid-range product  Regularly busy  Regularly busy           Most orders
# 17  Mid-range product      Least busy      Least busy           Most orders
# 18  Mid-range product  Regularly busy      Least busy           Most orders
# 19  Mid-range product  Regularly busy      Least busy        Average orders
# 20  Mid-range product  Regularly busy      Least busy           Most orders
# 21  Mid-range product      Least busy      Least busy           Most orders
# 22  Mid-range product      Least busy      Least busy           Most orders
# 23  Mid-range product  Regularly busy     Busiest day        Average orders
# 24  Mid-range product  Regularly busy     Busiest day           Most orders
# 25  Mid-range product  Regularly busy     Busiest day           Most orders
# 26  Mid-range product  Regularly busy  Regularly busy           Most orders
# 27  Mid-range product  Regularly busy  Regularly busy        Average orders
# 28  Mid-range product  Regularly busy     Busiest day           Most orders
# 29  Mid-range product  Regularly busy  Regularly busy           Most orders
# 30  Mid-range product  Regularly busy  Regularly busy        Average orders
# 31  Mid-range product  Regularly busy     Busiest day           Most orders
# 32  Mid-range product  Regularly busy  Regularly busy           Most orders
# 33  Mid-range product  Regularly busy  Regularly busy           Most orders
# 34  Mid-range product  Regularly busy  Regularly busy           Most orders
# 35  Mid-range product  Regularly busy      Least busy        Average orders
# 36  Mid-range product  Regularly busy  Regularly busy           Most orders
# 37  Mid-range product  Regularly busy      Least busy           Most orders
# 38  Mid-range product  Regularly busy     Busiest day           Most orders
# 39  Mid-range product  Regularly busy     Busiest day           Most orders
# 40  Mid-range product  Regularly busy  Regularly busy        Average orders
# 41  Mid-range product  Regularly busy      Least busy           Most orders
# 42  Mid-range product  Regularly busy      Least busy           Most orders
# 43  Mid-range product  Regularly busy  Regularly busy           Most orders
# 44  Mid-range product  Regularly busy  Regularly busy           Most orders
# 45  Mid-range product  Regularly busy     Busiest day           Most orders
# 46  Mid-range product  Regularly busy     Busiest day           Most orders
# 47  Mid-range product  Regularly busy  Regularly busy           Most orders
# 48  Mid-range product  Regularly busy     Busiest day           Most orders
# 49  Mid-range product  Regularly busy     Busiest day        Average orders
# 50  Mid-range product      Least busy      Least busy           Most orders
# 51  Mid-range product  Regularly busy  Regularly busy           Most orders
# 52  Mid-range product     Busiest day     Busiest day           Most orders
# 53  Mid-range product  Regularly busy     Busiest day        Average orders
# 54  Mid-range product  Regularly busy     Busiest day           Most orders
# 55  Mid-range product  Regularly busy     Busiest day           Most orders
# 56  Mid-range product  Regularly busy     Busiest day        Average orders
# 57  Mid-range product  Regularly busy  Regularly busy        Average orders
# 58  Mid-range product  Regularly busy      Least busy           Most orders
# 59  Mid-range product  Regularly busy  Regularly busy           Most orders
# 60  Mid-range product     Busiest day     Busiest day           Most orders
# 61  Mid-range product      Least busy      Least busy        Average orders
# 62  Mid-range product  Regularly busy     Busiest day           Most orders
# 63  Mid-range product  Regularly busy  Regularly busy           Most orders
# 64  Mid-range product  Regularly busy  Regularly busy           Most orders
# 65  Mid-range product  Regularly busy     Busiest day           Most orders
# 66  Mid-range product  Regularly busy  Regularly busy           Most orders
# 67  Mid-range product     Busiest day     Busiest day        Average orders
# 68  Mid-range product  Regularly busy  Regularly busy           Most orders
# 69  Mid-range product  Regularly busy      Least busy        Average orders
# 70  Mid-range product      Least busy      Least busy           Most orders
# 71  Mid-range product  Regularly busy  Regularly busy           Most orders
# 72  Mid-range product      Least busy      Least busy           Most orders
# 73  Mid-range product  Regularly busy  Regularly busy        Average orders
# 74  Mid-range product  Regularly busy      Least busy           Most orders
# 75  Mid-range product  Regularly busy      Least busy           Most orders
# 76  Mid-range product  Regularly busy  Regularly busy        Average orders
# 77  Mid-range product  Regularly busy     Busiest day           Most orders
# 78  Mid-range product  Regularly busy     Busiest day           Most orders
# 79  Mid-range product  Regularly busy     Busiest day        Average orders
# 80  Mid-range product  Regularly busy  Regularly busy           Most orders
# 81  Mid-range product  Regularly busy  Regularly busy           Most orders
# 82  Mid-range product  Regularly busy     Busiest day           Most orders
# 83  Mid-range product  Regularly busy  Regularly busy        Average orders
# 84  Mid-range product  Regularly busy      Least busy           Most orders
# 85  Mid-range product  Regularly busy  Regularly busy           Most orders
# 86  Mid-range product  Regularly busy      Least busy           Most orders
# 87  Mid-range product  Regularly busy  Regularly busy           Most orders
# 88  Mid-range product  Regularly busy      Least busy           Most orders
# 89  Mid-range product      Least busy      Least busy           Most orders
# 90  Mid-range product  Regularly busy  Regularly busy           Most orders
# 91  Mid-range product  Regularly busy  Regularly busy           Most orders
# 92  Mid-range product  Regularly busy  Regularly busy        Average orders
# 93  Mid-range product  Regularly busy  Regularly busy           Most orders
# 94  Mid-range product  Regularly busy  Regularly busy           Most orders
# 95  Mid-range product  Regularly busy  Regularly busy           Most orders
# 96  Mid-range product  Regularly busy  Regularly busy           Most orders
# 97  Mid-range product      Least busy      Least busy           Most orders
# 98  Mid-range product  Regularly busy     Busiest day        Average orders
# 99  Mid-range product  Regularly busy      Least busy        Average orders
#
#     max_order
# 0          10
# 1          10
# 2          10
# 3          10
# 4          10
# 5          10
# 6          10
# 7          10
# 8          10
# 9          10
# 10         22
# 11         22
# 12         22
# 13         22
# 14         22
# 15          9
# 16          9
# 17          9
# 18         33
# 19         20
# 20         20
# 21         11
# 22         11
# 23         27
# 24         27
# 25         27
# 26         27
# 27         27
# 28         27
# 29         27
# 30         27
# 31         27
# 32         27
# 33         27
# 34         27
# 35         27
# 36         27
# 37         24
# 38         24
# 39         24
# 40         24
# 41         24
# 42         24
# 43         24
# 44         24
# 45         24
# 46         24
# 47         24
# 48         24
# 49         24
# 50         24
# 51         24
# 52         24
# 53         24
# 54         24
# 55         24
# 56          7
# 57          7
# 58         19
# 59         19
# 60         19
# 61         19
# 62         19
# 63         19
# 64         19
# 65         19
# 66         19
# 67         14
# 68         14
# 69         14
# 70         14
# 71         14
# 72         14
# 73         14
# 74          6
# 75          3
# 76          3
# 77          6
# 78         58
# 79         58
# 80         58
# 81         58
# 82         58
# 83         58
# 84         58
# 85         58
# 86         58
# 87         58
# 88         58
# 89         58
# 90         70
# 91         70
# 92         51
# 93         51
# 94          8
# 95          3
# 96          3
# 97          8
# 98         22
# 99         22

# %% [markdown]
# ### Deriving Columns with loc()

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
ords_prods_merge['loyalty_flag'].value_counts (dropna = False)
# Out:
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: loyalty_flag, dtype: int64

# %%
ords_prods_merge[['user_id', 'loyalty_flag', 'order_number']].head(5)
# Out:
#    user_id  loyalty_flag  order_number
# 0        1  New customer             1
# 1        1  New customer             2
# 2        1  New customer             3
# 3        1  New customer             4
# 4        1  New customer             5
